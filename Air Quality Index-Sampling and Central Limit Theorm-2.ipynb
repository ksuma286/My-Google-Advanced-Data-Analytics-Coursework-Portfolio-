# %%
import pandas as pd

# %%
df=pd.read_csv('c4_epa_air_quality.csv')

# %% [markdown]
# This is an air quality index dataset Source-Google Advanced Data Analytics Certification Modified Dataset

# %%
df.head()
# Out:
#    Unnamed: 0  date_local    state_name   county_name      city_name  \
# 0           0  2018-01-01       Arizona      Maricopa        Buckeye
# 1           1  2018-01-01          Ohio       Belmont      Shadyside
# 2           2  2018-01-01       Wyoming         Teton  Not in a city
# 3           3  2018-01-01  Pennsylvania  Philadelphia   Philadelphia
# 4           4  2018-01-01          Iowa          Polk     Des Moines
#
#                                      local_site_name   parameter_name  \
# 0                                            BUCKEYE  Carbon monoxide
# 1                                          Shadyside  Carbon monoxide
# 2  Yellowstone National Park - Old Faithful Snow ...  Carbon monoxide
# 3                             North East Waste (NEW)  Carbon monoxide
# 4                                          CARPENTER  Carbon monoxide
#
#     units_of_measure  arithmetic_mean  aqi
# 0  Parts per million         0.473684    7
# 1  Parts per million         0.263158    5
# 2  Parts per million         0.111111    2
# 3  Parts per million         0.300000    3
# 4  Parts per million         0.215789    3

# %%
df.shape
# Out:
# (260, 10)

# %% [markdown]
# Sampling is taking a part of the entire population and aassuming that the insights from that sample will apply to the entire population.
#
# This can be checked using Central limit theory which states that the sample distribtion mean and sample distribution propotion are similar to the population mean and propotion.
#
# As the sample size(number of samples increases),the sample distribution mean and propotion become close to population mean and propotion.
#
# As the sample distribution mean become closer to the population mean it takes the shape of normal distribution,same applies to sample distribution of propotion.
#
# All of this is possible if the data sample is not biased.
#
# The difference between the population mean and sample distribution mean can be obtained by the formula STD/sqrt(n) n is sample size Standard error of mean.
#
# // Standard error of propotion is sqrt(p(1-p)/n) where p is (the percentage) propotion value we get
#
# The standard error becomes lower when dample mean becomes closer to population mean

# %%
df['aqi'].mean()
# Out:
# 6.757692307692308

# %%
from scipy import stats

# %%
sample1=df.sample(n=50,replace=False,random_state=4006)

# %% [markdown]
# n is number of records we want in our sample
# replace is if you want the row to be put back after it has beeb selected or you want to select it and not place it back.Non repetetion is better to avoid row dupliction

# %%
sample1['aqi'].mean()
# Out:
# 7.14

# %%
sample2=df.sample(n=50,replace=False,random_state=500056)

# %%
sample2['aqi'].mean()
# Out:
# 5.92

# %%
sample3=df.sample(n=50,replace=False,random_state=50)

# %%
sample3['aqi'].mean()
# Out:
# 6.3

# %%
sample10000=[]
for i in range(10000):
    sample10000.append(df.aqi.sample(n=50,replace=False).mean())
sample10000=pd.DataFrame(data={'samples_means':sample10000})

# %%
sample10000
# Out:
#       samples_means
# 0              6.88
# 1              6.64
# 2              7.48
# 3              7.12
# 4              7.08
# ...             ...
# 9995           9.36
# 9996           6.14
# 9997           7.84
# 9998           5.10
# 9999           9.44
#
# [10000 rows x 1 columns]

# %%
sample10000.samples_means.mean()
# Out:
# 6.749008000000024

# %% [markdown]
# Initally when we took 3 different samples of 50 the mean values were close to population values in first two cases and very close in third sample.

# %% [markdown]
# When we created 10000 random 50 different samples,we found the mean of 10000 samples means is very close to population mean of original dataset.Central limit theorm applies

# %%
sample10000.hist()
# Out:
# array([[<AxesSubplot:title={'center':'samples_means'}>]], dtype=object)

# %% [markdown]
# It has normal distribution too for 10000 samples

# %%
import numpy as np

# %%
standard_error_mean=sample10000.std()/np.sqrt(len(sample10000))
standard_error_mean
# Out:
# samples_means    0.008988
# dtype: float64

# %% [markdown]
# now let us consider the first sample

# %%
sample1
# Out:
#      Unnamed: 0  date_local            state_name            county_name  \
# 177         177  2018-01-01            California            Los Angeles
# 121         121  2018-01-01        North Carolina            Mecklenburg
# 212         212  2018-01-01             Minnesota               Hennepin
# 8             8  2018-01-01                Hawaii               Honolulu
# 220         220  2018-01-01            California                   Napa
# 252         252  2018-01-01                  Ohio               Hamilton
# 206         206  2018-01-01            California         San Bernardino
# 155         155  2018-01-01               Arizona               Maricopa
# 96           96  2018-01-01             Minnesota                 Dakota
# 26           26  2018-01-01            California                 Orange
# 243         243  2018-01-01                Alaska  Fairbanks North Star
# 4             4  2018-01-01                  Iowa                   Polk
# 176         176  2018-01-01            California           Contra Costa
# 246         246  2018-01-01            Washington                   King
# 255         255  2018-01-01  District Of Columbia   District of Columbia
# 171         171  2018-01-01            California                   Inyo
# 199         199  2018-01-01            California              Riverside
# 174         174  2018-01-01              Oklahoma                  Adair
# 116         116  2018-01-01              Virginia          Richmond City
# 126         126  2018-01-01               Florida                Broward
# 129         129  2018-01-01              Michigan                  Wayne
# 104         104  2018-01-01               Arizona                   Pima
# 168         168  2018-01-01              Illinois            Saint Clair
# 205         205  2018-01-01             Tennessee                 Shelby
# 98           98  2018-01-01               Vermont             Chittenden
# 257         257  2018-01-01              Kentucky              Jefferson
# 231         231  2018-01-01                  Ohio             Montgomery
# 159         159  2018-01-01            New Jersey                 Camden
# 79           79  2018-01-01          Pennsylvania           Philadelphia
# 71           71  2018-01-01               Alabama              Jefferson
# 84           84  2018-01-01              Kentucky               Edmonson
# 225         225  2018-01-01                  Utah              Salt Lake
# 94           94  2018-01-01               Florida               Pinellas
# 53           53  2018-01-01          South Dakota              Minnehaha
# 247         247  2018-01-01                 Texas                 Dallas
# 189         189  2018-01-01            California            Los Angeles
# 109         109  2018-01-01            California            Los Angeles
# 134         134  2018-01-01            California                Alameda
# 154         154  2018-01-01                 Idaho                    Ada
# 152         152  2018-01-01             Louisiana       East Baton Rouge
# 36           36  2018-01-01         Massachusetts                Suffolk
# 125         125  2018-01-01                  Utah              Salt Lake
# 0             0  2018-01-01               Arizona               Maricopa
# 49           49  2018-01-01             Tennessee                 Shelby
# 101         101  2018-01-01          Pennsylvania                  Adams
# 81           81  2018-01-01            California          Santa Barbara
# 160         160  2018-01-01           Mississippi                  Hinds
# 5             5  2018-01-01                Hawaii               Honolulu
# 146         146  2018-01-01         New Hampshire           Hillsborough
# 140         140  2018-01-01                 Texas                 Harris
#
#                                      city_name  \
# 177                                 Long Beach
# 121                                  Charlotte
# 212                                Minneapolis
# 8                                     Honolulu
# 220                                       Napa
# 252                                 Cincinnati
# 206                             San Bernardino
# 155                                    Phoenix
# 96   Inver Grove Heights (RR name Inver Grove)
# 26                                    La Habra
# 243                                  Fairbanks
# 4                                   Des Moines
# 176                              Bethel Island
# 246                                    Seattle
# 255                                 Washington
# 171                              Not in a city
# 199                                   Rubidoux
# 174                                Cherry Tree
# 116                                   Richmond
# 126                            Fort Lauderdale
# 129                                    Detroit
# 104                                     Tucson
# 168                           East Saint Louis
# 205                                    Memphis
# 98                                  Burlington
# 257                                 Louisville
# 231                                     Dayton
# 159                                     Camden
# 79                                Philadelphia
# 71                                  Birmingham
# 84                               Not in a city
# 225                             Salt Lake City
# 94                            Saint Petersburg
# 53                                 Sioux Falls
# 247                                     Dallas
# 189                                     Pomona
# 109                                Los Angeles
# 134                                    Oakland
# 154          Boise (corporate name Boise City)
# 152                                Baton Rouge
# 36                                      Boston
# 125                             Salt Lake City
# 0                                      Buckeye
# 49                                     Memphis
# 101                              Not in a city
# 81                   Vandenberg Air Force Base
# 160                                    Jackson
# 5                                Not in a city
# 146                   Peterborough (Peterboro)
# 140                                  Deer Park
#
#                                        local_site_name   parameter_name  \
# 177                                Long Beach (Hudson)  Carbon monoxide
# 121                               Garinger High School  Carbon monoxide
# 212                       Hennepin Center for the Arts  Carbon monoxide
# 8                                             Honolulu  Carbon monoxide
# 220                                               Napa  Carbon monoxide
# 252                               Cincinnati Near Road  Carbon monoxide
# 206                                     San Bernardino  Carbon monoxide
# 155                                      SOUTH PHOENIX  Carbon monoxide
# 96                            Flint Hills Refinery 423  Carbon monoxide
# 26                                            La Habra  Carbon monoxide
# 243                                              NCORE  Carbon monoxide
# 4                                            CARPENTER  Carbon monoxide
# 176                                      Bethel Island  Carbon monoxide
# 246                              Seattle-10th & Weller  Carbon monoxide
# 255                                          Near Road  Carbon monoxide
# 171  White Mountain Research Center - Owens Valley Lab  Carbon monoxide
# 199                                           Rubidoux  Carbon monoxide
# 174                                           STILWELL  Carbon monoxide
# 116                                         Bryan Park  Carbon monoxide
# 126                        Near Road - Fort Lauderdale  Carbon monoxide
# 129                                           ELIZA-NR  Carbon monoxide
# 104                                    22ND & ALVERNON  Carbon monoxide
# 168                                  IEPA-RAPS TRAILER  Carbon monoxide
# 205  Near Road Site at Southwest Tennessee Communit...  Carbon monoxide
# 98                      City of Burlington Parking Lot  Carbon monoxide
# 257                                       CANNONS LANE  Carbon monoxide
# 231                                            Reibold  Carbon monoxide
# 159                               Camden Spruce Street  Carbon monoxide
# 79                           Car-Barn Montgomery I -76  Carbon monoxide
# 71                               Arkadelphia/Near Road  Carbon monoxide
# 84                    Mammoth Cave NP - Houchin Meadow  Carbon monoxide
# 225                                          ROSE PARK  Carbon monoxide
# 94                      Sawgrass Lake Park (Near-Road)  Carbon monoxide
# 53                              SD School for the Deaf  Carbon monoxide
# 247                                      Dallas Hinton  Carbon monoxide
# 189                                             Pomona  Carbon monoxide
# 109                      Los Angeles-North Main Street  Carbon monoxide
# 134                                            Oakland  Carbon monoxide
# 154                             Boise - Eastman Garage  Carbon monoxide
# 152                                            Capitol  Carbon monoxide
# 36                                      VON HILLERN ST  Carbon monoxide
# 125                                          Hawthorne  Carbon monoxide
# 0                                              BUCKEYE  Carbon monoxide
# 49                                  Memphis NCORE site  Carbon monoxide
# 101                           NARSTO SITE ARENDTSVILLE  Carbon monoxide
# 81                                     VAFB South Base  Carbon monoxide
# 160                                      Jackson NCORE  Carbon monoxide
# 5                                              Kapolei  Carbon monoxide
# 146                                  MILLER STATE PARK  Carbon monoxide
# 140                               Houston Deer Park #2  Carbon monoxide
#
#       units_of_measure  arithmetic_mean  aqi
# 177  Parts per million         1.200000   24
# 121  Parts per million         0.200000    2
# 212  Parts per million         0.010526    1
# 8    Parts per million         0.400000    5
# 220  Parts per million         0.588889   10
# 252  Parts per million         0.226316    3
# 206  Parts per million         1.100000   28
# 155  Parts per million         1.394737   36
# 96   Parts per million         0.200000    2
# 26   Parts per million         0.673684   13
# 243  Parts per million         0.557895    8
# 4    Parts per million         0.215789    3
# 176  Parts per million         0.511111    7
# 246  Parts per million         0.384211    5
# 255  Parts per million         0.244444    3
# 171  Parts per million         0.100000    1
# 199  Parts per million         1.021053   23
# 174  Parts per million         0.166667    2
# 116  Parts per million         0.442105    7
# 126  Parts per million         0.373684    7
# 129  Parts per million         0.616667   11
# 104  Parts per million         0.168421    3
# 168  Parts per million         0.200000    2
# 205  Parts per million         0.284211    3
# 98   Parts per million         0.233333    3
# 257  Parts per million         0.163158    2
# 231  Parts per million         0.163158    2
# 159  Parts per million         0.200000    2
# 79   Parts per million         0.223529    3
# 71   Parts per million         0.200000    2
# 84   Parts per million         0.182353    2
# 225  Parts per million         0.363158   10
# 94   Parts per million         0.315789    9
# 53   Parts per million         0.242105    5
# 247  Parts per million         0.157895    2
# 189  Parts per million         1.000000   20
# 109  Parts per million         0.994737   17
# 134  Parts per million         0.600000   10
# 154  Parts per million         0.889474   14
# 152  Parts per million         0.000000    0
# 36   Parts per million         0.252632    3
# 125  Parts per million         0.694444   10
# 0    Parts per million         0.473684    7
# 49   Parts per million         0.100000    1
# 101  Parts per million         0.144444    2
# 81   Parts per million         0.200000    2
# 160  Parts per million         0.200000    2
# 5    Parts per million         0.994737   14
# 146  Parts per million         0.200000    2
# 140  Parts per million         0.200000    2

# %%
sample_final=sample1.iloc[:,1:]

# %%
sample_final.head()
# Out:
#      date_local      state_name  county_name    city_name  \
# 177  2018-01-01      California  Los Angeles   Long Beach
# 121  2018-01-01  North Carolina  Mecklenburg    Charlotte
# 212  2018-01-01       Minnesota     Hennepin  Minneapolis
# 8    2018-01-01          Hawaii     Honolulu     Honolulu
# 220  2018-01-01      California         Napa         Napa
#
#                   local_site_name   parameter_name   units_of_measure  \
# 177           Long Beach (Hudson)  Carbon monoxide  Parts per million
# 121          Garinger High School  Carbon monoxide  Parts per million
# 212  Hennepin Center for the Arts  Carbon monoxide  Parts per million
# 8                        Honolulu  Carbon monoxide  Parts per million
# 220                          Napa  Carbon monoxide  Parts per million
#
#      arithmetic_mean  aqi
# 177         1.200000   24
# 121         0.200000    2
# 212         0.010526    1
# 8           0.400000    5
# 220         0.588889   10

# %%
sample_final.aqi.std()/np.sqrt(len(sample_final))
# Out:
# 1.0987971159594554

# %% [markdown]
# standard error of mean is low arround 1 std which means by empirical law 68% districts have satisfactory AQI i.e
# below 100 AQI

# %% [markdown]
# The mean AQI in a sample of 50 observations was below 100 in a statistically significant sense . For reference, AQI values at or below 100 are generally thought of as satisfactory.
